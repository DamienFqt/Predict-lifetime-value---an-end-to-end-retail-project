# %%
class Magie:
    def __init__(self):
        print("Un nouveau sorcier est détécté")
        self.ville="Toulouse"
        self.competence=0
        self.nom="Nom"
        self.prenom="Prenom"

    def monter_competence(self, valeur):
        self.competence +=valeur
        return print("Le niveau de l'élève est de",self.competence)

    def update_identite(self,nom,prenom):
        self.nom=nom
        self.prenom=prenom
        print(self.nom, self.prenom)

    def fiche_sorcier(self):
        print(self.nom, " ", self.prenom, " ", self.competence)

eleve1=Magie()
eleve1.update_identite("Lucile","Comolet")

eleve1.monter_competence(15)


eleve1.monter_competence(10)

eleve1.fiche_sorcier()
# Out:
# Un nouveau sorcier est détécté
# Lucile Comolet
# Le niveau de l'élève est de 15
# Le niveau de l'élève est de 25
# Lucile   Comolet   25

# %%
for metric_name, metric in scoring.items():
    if metric_name in ["precision", "recall", "f1"]:

        if metric_name == "precision":
            scoring_with_threshold["precision_threshold"] = (
                _threshold_scorer(precision_score, threshold)
            )

        elif metric_name == "recall":
            scoring_with_threshold["recall_threshold"] = (
                _threshold_scorer(recall_score, threshold)
            )

        elif metric_name == "f1":
            scoring_with_threshold["f1_threshold"] = (
                _threshold_scorer(f1_score, threshold)
            )

    else:
        scoring_with_threshold[metric_name] = metric
# Out:
# 6

# %%
import numpy as np

np.log(84786751)-np.cos(453.46)+np.arccosh(85)
# Out:
# 22.91186665371786
